# %%
import numpy as np 
import csv 
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data= pd.read_csv("ex1data1.txt")
tData = np.array(data)
n =tData.shape[0]
X= np.zeros(tData.shape[0])
Y= np.zeros(tData.shape[0])
index= 0

for i in tData: 
    X[index] = tData[index, 0]
    Y[index] = tData[index, 1]
    index+=1

plt.ylabel("Profit in $10,000s")
plt.xlabel("Population of City in 10,000s")
plt.title("title")
plt.scatter(X,Y)
plt.show()
